# %%
# !huggingface-cli login
# Out:
# ⚠️  Warning: 'huggingface-cli login' is deprecated. Use 'hf auth login' instead.
#
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     To log in, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# Enter your token (input will not be visible):
# Add token as git credential? (Y/n) n
# Token is valid (permission: read).
# The token `Mehrab_1` has been saved to /root/.cache/huggingface/stored_tokens
# Your token has been saved to /root/.cache/huggingface/token
# Login successful.
# The current active token is: `Mehrab_1`

# %%
# !pip install decord
# Out:
# Collecting decord
#   Downloading decord-0.6.0-py3-none-manylinux2010_x86_64.whl.metadata (422 bytes)
# Requirement already satisfied: numpy>=1.14.0 in /usr/local/lib/python3.12/dist-packages (from decord) (2.0.2)
# Downloading decord-0.6.0-py3-none-manylinux2010_x86_64.whl (13.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.6/13.6 MB 134.0 MB/s eta 0:00:00
# Installing collected packages: decord
# Successfully installed decord-0.6.0

# %%
import os, gc, cv2, glob, numpy as np, pandas as pd
import matplotlib.pyplot as plt, seaborn as sns
from tqdm import tqdm
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, auc

# %%
import tensorflow as tf
from tensorflow.keras.applications import ResNet50
from tensorflow.keras import layers, models, optimizers, callbacks
from datasets import load_dataset
from decord import VideoReader, cpu

# %% [markdown]
# #Load_data

# %%
from datasets import load_dataset
dataset = load_dataset("nexar-ai/nexar_collision_prediction")
# Out:
# Resolving data files:   0%|          | 0/1502 [00:00<?, ?it/s]
# Resolving data files:   0%|          | 0/1348 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0/1502 [00:00<?, ?files/s]
# Downloading data:   0%|          | 0/1348 [00:00<?, ?files/s]
# test-public/positive/02270.mp4:   0%|          | 0.00/3.49M [00:00<?, ?B/s]
# test-public/positive/02319.mp4:   0%|          | 0.00/3.64M [00:00<?, ?B/s]
# test-public/positive/02276.mp4:   0%|          | 0.00/4.16M [00:00<?, ?B/s]
# test-public/positive/02282.mp4:   0%|          | 0.00/3.66M [00:00<?, ?B/s]
# test-public/positive/02280.mp4:   0%|          | 0.00/3.49M [00:00<?, ?B/s]
# test-public/positive/02306.mp4:   0%|          | 0.00/4.49M [00:00<?, ?B/s]
# test-public/positive/02266.mp4:   0%|          | 0.00/3.95M [00:00<?, ?B/s]
# test-public/positive/02330.mp4:   0%|          | 0.00/3.16M [00:00<?, ?B/s]
# test-public/positive/02316.mp4:   0%|          | 0.00/3.35M [00:00<?, ?B/s]
# test-public/positive/02305.mp4:   0%|          | 0.00/6.47M [00:00<?, ?B/s]
# test-public/positive/02287.mp4:   0%|          | 0.00/3.73M [00:00<?, ?B/s]
# test-public/positive/02335.mp4:   0%|          | 0.00/3.80M [00:00<?, ?B/s]
# test-public/positive/02297.mp4:   0%|          | 0.00/2.43M [00:00<?, ?B/s]
# test-public/positive/02279.mp4:   0%|          | 0.00/4.47M [00:00<?, ?B/s]
# test-public/positive/02283.mp4:   0%|          | 0.00/7.03M [00:00<?, ?B/s]
# test-public/positive/02322.mp4:   0%|          | 0.00/4.23M [00:00<?, ?B/s]
# test-public/positive/02336.mp4:   0%|          | 0.00/4.42M [00:00<?, ?B/s]
# test-public/positive/02345.mp4:   0%|          | 0.00/2.28M [00:00<?, ?B/s]
# test-public/positive/02354.mp4:   0%|          | 0.00/3.36M [00:00<?, ?B/s]
# test-public/positive/02366.mp4:   0%|          | 0.00/2.56M [00:00<?, ?B/s]
# test-public/positive/02368.mp4:   0%|          | 0.00/2.96M [00:00<?, ?B/s]
# test-public/positive/02370.mp4:   0%|          | 0.00/2.09M [00:00<?, ?B/s]
# test-public/positive/02371.mp4:   0%|          | 0.00/7.36M [00:00<?, ?B/s]
# test-public/positive/02369.mp4:   0%|          | 0.00/6.06M [00:00<?, ?B/s]
# test-public/positive/02373.mp4:   0%|          | 0.00/2.98M [00:00<?, ?B/s]
# test-public/positive/02374.mp4:   0%|          | 0.00/3.00M [00:00<?, ?B/s]
# test-public/positive/02379.mp4:   0%|          | 0.00/4.47M [00:00<?, ?B/s]
# test-public/positive/02384.mp4:   0%|          | 0.00/4.53M [00:00<?, ?B/s]
# test-public/positive/02385.mp4:   0%|          | 0.00/5.55M [00:00<?, ?B/s]
# test-public/positive/02387.mp4:   0%|          | 0.00/2.36M [00:00<?, ?B/s]
# test-public/positive/02378.mp4:   0%|          | 0.00/3.66M [00:00<?, ?B/s]
# test-public/positive/02396.mp4:   0%|          | 0.00/1.94M [00:00<?, ?B/s]
# test-public/positive/02401.mp4:   0%|          | 0.00/2.03M [00:00<?, ?B/s]
# test-public/positive/02397.mp4:   0%|          | 0.00/2.62M [00:00<?, ?B/s]
# test-public/positive/02410.mp4:   0%|          | 0.00/2.32M [00:00<?, ?B/s]
# test-public/positive/02391.mp4:   0%|          | 0.00/3.03M [00:00<?, ?B/s]
# test-public/positive/02413.mp4:   0%|          | 0.00/5.79M [00:00<?, ?B/s]
# test-public/positive/02428.mp4:   0%|          | 0.00/2.68M [00:00<?, ?B/s]
# test-public/positive/02433.mp4:   0%|          | 0.00/3.46M [00:00<?, ?B/s]
# test-public/positive/02429.mp4:   0%|          | 0.00/7.21M [00:00<?, ?B/s]
# test-public/positive/02434.mp4:   0%|          | 0.00/2.91M [00:00<?, ?B/s]
# test-public/positive/02442.mp4:   0%|          | 0.00/2.85M [00:00<?, ?B/s]
# test-public/positive/02441.mp4:   0%|          | 0.00/5.50M [00:00<?, ?B/s]
# test-public/positive/02448.mp4:   0%|          | 0.00/9.49M [00:00<?, ?B/s]
# test-public/positive/02454.mp4:   0%|          | 0.00/3.18M [00:00<?, ?B/s]
# test-public/positive/02459.mp4:   0%|          | 0.00/3.70M [00:00<?, ?B/s]
# test-public/positive/02468.mp4:   0%|          | 0.00/4.61M [00:00<?, ?B/s]
# test-public/positive/02472.mp4:   0%|          | 0.00/6.33M [00:00<?, ?B/s]
# test-public/positive/02474.mp4:   0%|          | 0.00/4.10M [00:00<?, ?B/s]
# test-public/positive/02476.mp4:   0%|          | 0.00/3.62M [00:00<?, ?B/s]
# test-public/positive/02473.mp4:   0%|          | 0.00/3.64M [00:00<?, ?B/s]
# test-public/positive/02479.mp4:   0%|          | 0.00/4.68M [00:00<?, ?B/s]
# test-public/positive/02482.mp4:   0%|          | 0.00/6.01M [00:00<?, ?B/s]
# test-public/positive/02494.mp4:   0%|          | 0.00/6.23M [00:00<?, ?B/s]
# test-public/positive/02495.mp4:   0%|          | 0.00/4.22M [00:00<?, ?B/s]
# test-public/positive/02496.mp4:   0%|          | 0.00/3.60M [00:00<?, ?B/s]
# test-public/positive/02499.mp4:   0%|          | 0.00/4.64M [00:00<?, ?B/s]
# test-public/positive/02501.mp4:   0%|          | 0.00/4.33M [00:00<?, ?B/s]
# test-public/positive/02500.mp4:   0%|          | 0.00/4.01M [00:00<?, ?B/s]
# test-public/positive/02505.mp4:   0%|          | 0.00/5.24M [00:00<?, ?B/s]
# test-public/positive/02502.mp4:   0%|          | 0.00/5.12M [00:00<?, ?B/s]
# test-public/positive/02509.mp4:   0%|          | 0.00/2.98M [00:00<?, ?B/s]
# test-public/positive/02522.mp4:   0%|          | 0.00/3.29M [00:00<?, ?B/s]
# test-public/positive/02518.mp4:   0%|          | 0.00/5.21M [00:00<?, ?B/s]
# test-public/positive/02511.mp4:   0%|          | 0.00/4.17M [00:00<?, ?B/s]
# test-public/positive/02512.mp4:   0%|          | 0.00/4.77M [00:00<?, ?B/s]
# test-public/positive/02533.mp4:   0%|          | 0.00/7.75M [00:00<?, ?B/s]
# test-public/positive/02543.mp4:   0%|          | 0.00/6.49M [00:00<?, ?B/s]
# test-public/positive/02537.mp4:   0%|          | 0.00/4.15M [00:00<?, ?B/s]
# test-public/positive/02548.mp4:   0%|          | 0.00/8.98M [00:00<?, ?B/s]
# test-public/positive/02557.mp4:   0%|          | 0.00/2.25M [00:00<?, ?B/s]
# test-public/positive/02556.mp4:   0%|          | 0.00/4.71M [00:00<?, ?B/s]
# test-public/positive/02561.mp4:   0%|          | 0.00/4.38M [00:00<?, ?B/s]
# test-public/positive/02563.mp4:   0%|          | 0.00/5.09M [00:00<?, ?B/s]
# test-public/positive/02566.mp4:   0%|          | 0.00/1.99M [00:00<?, ?B/s]
# test-public/positive/02582.mp4:   0%|          | 0.00/3.24M [00:00<?, ?B/s]
# test-public/positive/02579.mp4:   0%|          | 0.00/6.49M [00:00<?, ?B/s]
# test-public/positive/02567.mp4:   0%|          | 0.00/2.19M [00:00<?, ?B/s]
# test-public/positive/02581.mp4:   0%|          | 0.00/4.79M [00:00<?, ?B/s]
# test-public/positive/02595.mp4:   0%|          | 0.00/2.26M [00:00<?, ?B/s]
# test-public/positive/02594.mp4:   0%|          | 0.00/3.65M [00:00<?, ?B/s]
# test-public/positive/02599.mp4:   0%|          | 0.00/3.02M [00:00<?, ?B/s]
# test-public/positive/02612.mp4:   0%|          | 0.00/3.76M [00:00<?, ?B/s]
# test-public/positive/02613.mp4:   0%|          | 0.00/2.93M [00:00<?, ?B/s]
# test-public/positive/02615.mp4:   0%|          | 0.00/3.52M [00:00<?, ?B/s]
# test-public/positive/02600.mp4:   0%|          | 0.00/2.33M [00:00<?, ?B/s]
# test-public/positive/02620.mp4:   0%|          | 0.00/7.65M [00:00<?, ?B/s]
# test-public/positive/02608.mp4:   0%|          | 0.00/2.88M [00:00<?, ?B/s]
# test-public/positive/02628.mp4:   0%|          | 0.00/8.07M [00:00<?, ?B/s]
# test-public/positive/02632.mp4:   0%|          | 0.00/2.90M [00:00<?, ?B/s]
# test-public/positive/02635.mp4:   0%|          | 0.00/5.73M [00:00<?, ?B/s]
# test-public/positive/02639.mp4:   0%|          | 0.00/8.36M [00:00<?, ?B/s]
# test-public/positive/02636.mp4:   0%|          | 0.00/3.12M [00:00<?, ?B/s]
# test-public/positive/02655.mp4:   0%|          | 0.00/3.31M [00:00<?, ?B/s]
# test-public/positive/02656.mp4:   0%|          | 0.00/6.85M [00:00<?, ?B/s]
# test-public/positive/02666.mp4:   0%|          | 0.00/5.81M [00:00<?, ?B/s]
# test-public/positive/02683.mp4:   0%|          | 0.00/3.92M [00:00<?, ?B/s]
# test-public/positive/02673.mp4:   0%|          | 0.00/6.37M [00:00<?, ?B/s]
# test-public/positive/02687.mp4:   0%|          | 0.00/3.36M [00:00<?, ?B/s]
# test-public/positive/02686.mp4:   0%|          | 0.00/4.14M [00:00<?, ?B/s]
# test-public/positive/02674.mp4:   0%|          | 0.00/4.83M [00:00<?, ?B/s]
# test-public/positive/02691.mp4:   0%|          | 0.00/4.03M [00:00<?, ?B/s]
# test-public/positive/02692.mp4:   0%|          | 0.00/4.88M [00:00<?, ?B/s]
# test-public/positive/02702.mp4:   0%|          | 0.00/5.12M [00:00<?, ?B/s]
# test-public/positive/02695.mp4:   0%|          | 0.00/3.67M [00:00<?, ?B/s]
# test-public/positive/02713.mp4:   0%|          | 0.00/3.37M [00:00<?, ?B/s]
# test-public/positive/02693.mp4:   0%|          | 0.00/4.09M [00:00<?, ?B/s]
# test-public/positive/02703.mp4:   0%|          | 0.00/5.19M [00:00<?, ?B/s]
# test-public/positive/02708.mp4:   0%|          | 0.00/10.2M [00:00<?, ?B/s]
# test-public/positive/02700.mp4:   0%|          | 0.00/3.16M [00:00<?, ?B/s]
# test-public/positive/02725.mp4:   0%|          | 0.00/2.33M [00:00<?, ?B/s]
# test-public/positive/02730.mp4:   0%|          | 0.00/7.24M [00:00<?, ?B/s]
# test-public/positive/02739.mp4:   0%|          | 0.00/3.77M [00:00<?, ?B/s]
# test-public/positive/02741.mp4:   0%|          | 0.00/2.99M [00:00<?, ?B/s]
# test-public/positive/02736.mp4:   0%|          | 0.00/7.37M [00:00<?, ?B/s]
# test-public/positive/02744.mp4:   0%|          | 0.00/2.82M [00:00<?, ?B/s]
# test-public/positive/02745.mp4:   0%|          | 0.00/4.76M [00:00<?, ?B/s]
# test-public/positive/02746.mp4:   0%|          | 0.00/4.46M [00:00<?, ?B/s]
# test-public/positive/02747.mp4:   0%|          | 0.00/2.80M [00:00<?, ?B/s]
# test-public/positive/02749.mp4:   0%|          | 0.00/4.25M [00:00<?, ?B/s]
# test-public/positive/02751.mp4:   0%|          | 0.00/3.27M [00:00<?, ?B/s]
# test-public/positive/02765.mp4:   0%|          | 0.00/4.78M [00:00<?, ?B/s]
# test-public/positive/02758.mp4:   0%|          | 0.00/3.64M [00:00<?, ?B/s]
# test-public/positive/02769.mp4:   0%|          | 0.00/6.43M [00:00<?, ?B/s]
# test-public/positive/02764.mp4:   0%|          | 0.00/3.75M [00:00<?, ?B/s]
# test-public/positive/02767.mp4:   0%|          | 0.00/4.00M [00:00<?, ?B/s]
# test-public/positive/02771.mp4:   0%|          | 0.00/4.12M [00:00<?, ?B/s]
# test-public/positive/02781.mp4:   0%|          | 0.00/3.50M [00:00<?, ?B/s]
# test-public/positive/02783.mp4:   0%|          | 0.00/3.20M [00:00<?, ?B/s]
# test-public/positive/02786.mp4:   0%|          | 0.00/3.08M [00:00<?, ?B/s]
# test-public/positive/02787.mp4:   0%|          | 0.00/4.56M [00:00<?, ?B/s]
# test-public/positive/02800.mp4:   0%|          | 0.00/6.19M [00:00<?, ?B/s]
# test-public/positive/02804.mp4:   0%|          | 0.00/3.64M [00:00<?, ?B/s]
# test-public/positive/02793.mp4:   0%|          | 0.00/3.07M [00:00<?, ?B/s]
# test-public/positive/02794.mp4:   0%|          | 0.00/3.65M [00:00<?, ?B/s]
# test-public/positive/02801.mp4:   0%|          | 0.00/3.81M [00:00<?, ?B/s]
# test-public/positive/02807.mp4:   0%|          | 0.00/4.93M [00:00<?, ?B/s]
# test-public/positive/02809.mp4:   0%|          | 0.00/5.18M [00:00<?, ?B/s]
# test-public/positive/02812.mp4:   0%|          | 0.00/4.61M [00:00<?, ?B/s]
# test-public/positive/02833.mp4:   0%|          | 0.00/6.37M [00:00<?, ?B/s]
# test-public/positive/02828.mp4:   0%|          | 0.00/3.24M [00:00<?, ?B/s]
# test-public/positive/02818.mp4:   0%|          | 0.00/2.08M [00:00<?, ?B/s]
# test-public/positive/02831.mp4:   0%|          | 0.00/4.86M [00:00<?, ?B/s]
# test-public/positive/02816.mp4:   0%|          | 0.00/2.95M [00:00<?, ?B/s]
# test-public/positive/02840.mp4:   0%|          | 0.00/2.49M [00:00<?, ?B/s]
# test-public/positive/02836.mp4:   0%|          | 0.00/1.93M [00:00<?, ?B/s]
# test-public/positive/02856.mp4:   0%|          | 0.00/4.11M [00:00<?, ?B/s]
# test-public/positive/02868.mp4:   0%|          | 0.00/3.80M [00:00<?, ?B/s]
# test-public/positive/02845.mp4:   0%|          | 0.00/2.42M [00:00<?, ?B/s]
# test-public/positive/02855.mp4:   0%|          | 0.00/6.01M [00:00<?, ?B/s]
# test-public/positive/02873.mp4:   0%|          | 0.00/2.19M [00:00<?, ?B/s]
# test-public/positive/02854.mp4:   0%|          | 0.00/4.46M [00:00<?, ?B/s]
# test-public/positive/02866.mp4:   0%|          | 0.00/2.78M [00:00<?, ?B/s]
# test-public/positive/02870.mp4:   0%|          | 0.00/2.05M [00:00<?, ?B/s]
# test-public/positive/02885.mp4:   0%|          | 0.00/3.06M [00:00<?, ?B/s]
# test-public/positive/02888.mp4:   0%|          | 0.00/3.54M [00:00<?, ?B/s]
# test-public/positive/02889.mp4:   0%|          | 0.00/1.87M [00:00<?, ?B/s]
# test-public/positive/02903.mp4:   0%|          | 0.00/2.45M [00:00<?, ?B/s]
# test-public/positive/02890.mp4:   0%|          | 0.00/4.91M [00:00<?, ?B/s]
# test-public/positive/02915.mp4:   0%|          | 0.00/2.98M [00:00<?, ?B/s]
# metadata.csv: 0.00B [00:00, ?B/s]
# Generating train split:   0%|          | 0/1500 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/1344 [00:00<?, ? examples/s]

# %%
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['video', 'time_of_event', 'time_of_alert', 'light_conditions', 'weather', 'scene', 'time_to_accident'],
#         num_rows: 1500
#     })
#     test: Dataset({
#         features: ['video', 'time_of_event', 'time_of_alert', 'light_conditions', 'weather', 'scene', 'time_to_accident'],
#         num_rows: 1344
#     })
# })

# %% [markdown]
# #Preprocess

# %%
# مسیر cache دیتاست
base_path = "/root/.cache/huggingface/hub/datasets--nexar-ai--nexar_collision_prediction/snapshots"
snapshot_dir = [os.path.join(base_path, d) for d in os.listdir(base_path)][0]
print(" Dataset directory:", snapshot_dir)
# Out:
#  Dataset directory: /root/.cache/huggingface/hub/datasets--nexar-ai--nexar_collision_prediction/snapshots/aa97deda5a59f00bb7187739053b7c72e14374df

# %%
def build_dataframe(base_dir):
    positive_videos = glob.glob(f"{base_dir}/train/positive/*.mp4")
    negative_videos = glob.glob(f"{base_dir}/train/negative/*.mp4")
    data = [{"video_path": p, "label": 1} for p in positive_videos] + \
           [{"video_path": p, "label": 0} for p in negative_videos]
    df = pd.DataFrame(data)
    print(f"Loaded {len(df)} videos (Pos:{len(positive_videos)}, Neg:{len(negative_videos)})")
    return df

# %%
df = build_dataframe(snapshot_dir)
# Out:
# Loaded 1500 videos (Pos:750, Neg:750)

# %%
train_df, val_df = train_test_split(
    df, test_size=0.2, stratify=df["label"], random_state=42
    )
print("Train:", len(train_df), "Val:", len(val_df))
# Out:
# Train: 1200 Val: 300

# %% [markdown]
# #Frame

# %%
def load_video_frames(video_path, num_frames=32, size=(112,112), time_of_event=None):

    try:
        vr = VideoReader(video_path, ctx=cpu(0))
        total_frames = len(vr)
        fps = vr.get_avg_fps() if hasattr(vr, "get_avg_fps") else 30

        if time_of_event is not None and time_of_event > 0:
            event_frame = int(time_of_event * fps)
            start = max(event_frame - num_frames // 2, 0)
            end = min(event_frame + num_frames // 2, total_frames)
            indices = np.linspace(start, end - 1, num_frames, dtype=int)
        else:
            indices = np.linspace(0, total_frames - 1, num_frames, dtype=int)

        frames = vr.get_batch(indices).asnumpy()
        frames = np.array([cv2.resize(f, size) for f in frames])

        frames = frames.astype("float32") / 255.0
        return frames

    except Exception as e:
        print(f" خطا در خواندن ویدیو {video_path}: {e}")
        return None

# %%
def preprocess_split(df, num_videos=100, num_frames=32):

    X, y = [], []
    num_videos = min(num_videos, len(df))
    for i in tqdm(range(num_videos), desc="Extracting frames"):
        row = df.iloc[i]
        frames = load_video_frames(
            row["video_path"],
            num_frames=num_frames,
            time_of_event=row.get("time_of_event", None)
        )
        if frames is not None:
            X.append(frames)
            y.append(row["label"])
    return np.array(X), np.array(y)

# %%
X_train, y_train = preprocess_split(train_df, num_videos=400)
X_val, y_val = preprocess_split(val_df, num_videos=100)
# Out:
# Extracting frames: 100%|██████████| 400/400 [27:17<00:00,  4.09s/it]
# Extracting frames: 100%|██████████| 100/100 [07:00<00:00,  4.21s/it]

# %%
print("Shapes:", X_train.shape, y_train.shape)
print("Shapes:", X_val.shape, y_val.shape)
# Out:
# Shapes: (400, 32, 112, 112, 3) (400,)
# Shapes: (100, 32, 112, 112, 3) (100,)

# %%
from collections import Counter
counter = Counter(y_train)
counter1 = Counter(y_val)
print(counter)
print(counter1)
# Out:
# Counter({np.int64(1): 201, np.int64(0): 199})
# Counter({np.int64(1): 55, np.int64(0): 45})
